# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint
import warnings
warnings.filterwarnings('ignore')

# Import API key
from api_keys import gkey

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
cities_data=pd.read_csv("../output_data/cities.csv")
cities_data.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      talnakh  69.49   88.40     60.80      67.0        34.0        8.95
# 1        bluff -46.60  168.33     50.32      91.0       100.0       13.80
# 2  port alfred -33.59   26.89     60.57      70.0         0.0       14.52
# 3       hobart -42.88  147.33     48.20      61.0        13.0       12.75
# 4      qaanaaq  77.48  -69.36     42.49      73.0        70.0        2.13
#
#   Country        Date
# 0      RU  1596036971
# 1      NZ  1596036919
# 2      ZA  1596036937
# 3      AU  1596036878
# 4      GL  1596036972

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=gkey)
locations=cities_data[["Lat","Lng"]]
humidity_lvl=cities_data["Humidity"]

# %%
fig=gmaps.figure()
heat_layer=gmaps.heatmap_layer(locations,weights=humidity_lvl,dissipating=False,point_radius=2,
                              max_intensity=humidity_lvl.max())
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
cities_data.head()
top_spots=cities_data.loc[cities_data["Max Temp"] >= 65]
top_spots=cities_data.loc[cities_data["Max Temp"] <= 85]
top_spots=cities_data.loc[cities_data["Wind Speed"] <= 10]
top_spots.reset_index(drop=True, inplace=True)
top_spots
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       talnakh  69.49   88.40     60.80      67.0        34.0        8.95
# 1       qaanaaq  77.48  -69.36     42.49      73.0        70.0        2.13
# 2    lavrentiya  65.58 -171.00     47.59      90.0        95.0        4.81
# 3      khatanga  71.97  102.50     54.37      72.0         6.0        5.64
# 4      oksfjord  70.24   22.35     69.80      56.0       100.0        9.17
# ..          ...    ...     ...       ...       ...         ...         ...
# 405    mosquera   4.71  -74.23     60.80      63.0        75.0        6.93
# 406   caravelas -17.71  -39.25     79.75      57.0         0.0        7.74
# 407   los andes -32.83  -70.60     63.00      61.0         0.0        2.24
# 408    matagami  49.75  -77.63     62.60      93.0        75.0        4.41
# 409        tame   6.46  -71.73     84.72      65.0        25.0        5.55
#
#     Country        Date
# 0        RU  1596036971
# 1        GL  1596036972
# 2        RU  1596036972
# 3        RU  1596036973
# 4        NO  1596036974
# ..      ...         ...
# 405      CO  1596037160
# 406      BR  1596037161
# 407      CL  1596037161
# 408      CA  1596037161
# 409      CO  1596037162
#
# [410 rows x 9 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
top_spots.loc[:,"Hotel"]=""
top_spots.head()
top_spots.dtypes
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity      float64
# Cloudiness    float64
# Wind Speed    float64
# Country        object
# Date            int64
# Hotel          object
# dtype: object

# %%
params = {
    "key": gkey,
    "radius": 5000,
    "types": "hotel"
}
for index,row in top_spots.iterrows():
    lat=row["Lat"]
    lng=row["Lng"]
    params["location"]=f"{lat},{lng}"
    base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    results=requests.get(base_url,params=params)
    results=results.json()
    try:
        top_spots.loc[index,"Hotel"]=results["results"][0]["name"]
    except (KeyError, IndexError):
        print("Location missing...skipping")
print("-"*30)
print("Finished")
# Out:
# Location missing...skipping
# Location missing...skipping
# ------------------------------
# Finished

# %%
top_spots.head(10)
# Out:
#                   City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0              talnakh  69.49   88.40     60.80      67.0        34.0
# 1              qaanaaq  77.48  -69.36     42.49      73.0        70.0
# 2           lavrentiya  65.58 -171.00     47.59      90.0        95.0
# 3             khatanga  71.97  102.50     54.37      72.0         6.0
# 4             oksfjord  70.24   22.35     69.80      56.0       100.0
# 5               kodiak  57.79 -152.41     53.60      76.0         1.0
# 6           nanortalik  60.14  -45.24     47.08      92.0       100.0
# 7               meleuz  52.97   55.92     65.62      79.0        13.0
# 8              mataura -46.19  168.86     47.88      91.0       100.0
# 9  ouro preto do oeste -10.75  -62.22     92.30      30.0         0.0
#
#    Wind Speed Country        Date                Hotel
# 0        8.95      RU  1596036971              Norilsk
# 1        2.13      GL  1596036972              Qaanaaq
# 2        4.81      RU  1596036972           Lavrentiya
# 3        5.64      RU  1596036973             Chatanga
# 4        9.17      NO  1596036974             Øksfjord
# 5        6.93      US  1596036700               Kodiak
# 6        9.55      GL  1596036974           Nanortalik
# 7        4.00      RU  1596036974               Meleuz
# 8        3.27      NZ  1596036975              Mataura
# 9        6.44      BR  1596036975  Ouro Preto do Oeste

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
hotel_points=

# Display figure
fig
