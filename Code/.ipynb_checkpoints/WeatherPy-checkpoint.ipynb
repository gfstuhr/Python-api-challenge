# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint
from scipy.stats import linregress

# Import API key
from api_keys import owkey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Creating Dataframe
cities_data=pd.DataFrame(cities,columns=["City"])
labels=["Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Country","Date"]
for each_label in labels:
    cities_data[each_label]=""

# Fetching City Data
record=0
units="Imperial"
for index, row in cities_data.iterrows():
    city=row["City"]
    try:
        url_string=f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={owkey}&units={units}"
        response=requests.get(url_string)
        city_info=response.json()
        #feeding data into dataframe
        cities_data.loc[index,"Lat"]=city_info["coord"]["lat"]
        cities_data.loc[index,"Lng"]=city_info["coord"]["lon"]
        cities_data.loc[index,"Max Temp"]=city_info["main"]["temp_max"]
        cities_data.loc[index,"Humidity"]=city_info["main"]["humidity"]
        cities_data.loc[index,"Cloudiness"]=city_info["clouds"]["all"]
        cities_data.loc[index,"Wind Speed"]=city_info["wind"]["speed"]
        cities_data.loc[index,"Country"]=city_info["sys"]["country"]
        cities_data.loc[index,"Date"]=city_info["dt"]
        print(f"Processing Record {record}| {city}")
        record=record+1
    except KeyError:
        pass
        print(f"{city} did not exist. Skipping...")
print("-"*30)
print("End of Records")
# Out:
# Processing Record 0| butaritari
# Processing Record 1| saskylakh
# Processing Record 2| hilo
# Processing Record 3| busselton
# Processing Record 4| port blair
# Processing Record 5| ushuaia
# Processing Record 6| torbay
# Processing Record 7| kismayo
# Processing Record 8| mandalgovi
# Processing Record 9| katsuura
# Processing Record 10| barrow
# tsihombe did not exist. Skipping...
# Processing Record 11| buala
# Processing Record 12| jamestown
# Processing Record 13| husavik
# illoqqortoormiut did not exist. Skipping...
# Processing Record 14| upernavik
# taolanaro did not exist. Skipping...
# Processing Record 15| qaanaaq
# chagda did not exist. Skipping...
# Processing Record 16| georgetown
# Processing Record 17| pastos bons
# Processing Record 18| chokurdakh
# Processing Record 19| cape town
# Processing Record 20| dikson
# Processing Record 21| joao pinheiro
# Processing Record 22| kita
# Processing Record 23| sitka
# Processing Record 24| lensk
# Processing Record 25| la oroya
# Processing Record 26| bredasdorp
# Processing Record 27| new norfolk
# Processing Record 28| talnakh
# Processing Record 29| jingdezhen
# Processing Record 30| puerto madryn
# Processing Record 31| rikitea
# Processing Record 32| atuona
# longlac did not exist. Skipping...
# Processing Record 33| iqaluit
# Processing Record 34| carnarvon
# Processing Record 35| port elizabeth
# Processing Record 36| chalmette
# Processing Record 37| dabat
# Processing Record 38| punta arenas
# Processing Record 39| green valley
# Processing Record 40| vanimo
# Processing Record 41| puerto ayora
# Processing Record 42| mar del plata
# Processing Record 43| sinnamary
# Processing Record 44| mataura
# burica did not exist. Skipping...
# Processing Record 45| avarua
# Processing Record 46| hithadhoo
# Processing Record 47| belyy yar
# Processing Record 48| awjilah
# Processing Record 49| rio grande
# Processing Record 50| itarema
# Processing Record 51| hermanus
# Processing Record 52| shingu
# Processing Record 53| east london
# Processing Record 54| thunder bay
# Processing Record 55| yellowknife
# Processing Record 56| baykalsk
# Processing Record 57| kahului
# Processing Record 58| arona
# Processing Record 59| baruun-urt
# bargal did not exist. Skipping...
# Processing Record 60| leningradskiy
# Processing Record 61| kurilsk
# Processing Record 62| cairns
# Processing Record 63| grand gaube
# Processing Record 64| rogatica
# Processing Record 65| hobart
# Processing Record 66| gwadar
# Processing Record 67| khatanga
# Processing Record 68| ponta do sol
# Processing Record 69| dawlatabad
# Processing Record 70| rio gallegos
# Processing Record 71| lagoa vermelha
# Processing Record 72| mopipi
# Processing Record 73| ngunguru
# Processing Record 74| birjand
# Processing Record 75| tautira
# Processing Record 76| nemuro
# belushya guba did not exist. Skipping...
# Processing Record 77| arraial do cabo
# Processing Record 78| nanortalik
# Processing Record 79| etne
# Processing Record 80| vaini
# Processing Record 81| bintulu
# Processing Record 82| tuktoyaktuk
# Processing Record 83| usinsk
# Processing Record 84| solnechnyy
# Processing Record 85| port shepstone
# Processing Record 86| karratha
# Processing Record 87| albany
# Processing Record 88| salalah
# Processing Record 89| seymchan
# Processing Record 90| provideniya
# Processing Record 91| necochea
# Processing Record 92| castro
# Processing Record 93| ostrovnoy
# Processing Record 94| fort nelson
# ijaki did not exist. Skipping...
# Processing Record 95| bolshaya dzhalga
# Processing Record 96| esperance
# Processing Record 97| severo-kurilsk
# Processing Record 98| tevaitoa
# Processing Record 99| port-cartier
# Processing Record 100| harper
# Processing Record 101| bluff
# Processing Record 102| mount gambier
# Processing Record 103| san cristobal
# Processing Record 104| laizhou
# Processing Record 105| lagos
# Processing Record 106| chuy
# Processing Record 107| vitim
# Processing Record 108| oktyabrskoye
# Processing Record 109| ahipara
# Processing Record 110| baglan
# Processing Record 111| korla
# Processing Record 112| nova olimpia
# Processing Record 113| lorengau
# marcona did not exist. Skipping...
# Processing Record 114| hirara
# Processing Record 115| bilma
# Processing Record 116| ribeira grande
# Processing Record 117| christchurch
# Processing Record 118| lichuan
# Processing Record 119| shibganj
# Processing Record 120| marsh harbour
# Processing Record 121| touros
# Processing Record 122| jacareacanga
# Processing Record 123| puerto carreno
# Processing Record 124| lompoc
# Processing Record 125| longyearbyen
# Processing Record 126| cayenne
# Processing Record 127| pringsewu
# Processing Record 128| okha
# Processing Record 129| kamaishi
# Processing Record 130| surt
# Processing Record 131| kieta
# Processing Record 132| saldanha
# Processing Record 133| saint-philippe
# fort saint john did not exist. Skipping...
# Processing Record 134| kapaa
# Processing Record 135| anloga
# Processing Record 136| fortuna
# Processing Record 137| norman wells
# Processing Record 138| srednekolymsk
# Processing Record 139| orissaare
# Processing Record 140| paamiut
# Processing Record 141| igrim
# scottsburgh did not exist. Skipping...
# Processing Record 142| richards bay
# Processing Record 143| black diamond
# Processing Record 144| portobelo
# Processing Record 145| havre
# Processing Record 146| maura
# Processing Record 147| kalemie
# Processing Record 148| duki
# Processing Record 149| henties bay
# Processing Record 150| samarai
# Processing Record 151| west wendover
# jabiru did not exist. Skipping...
# Processing Record 152| townsville
# Processing Record 153| hermiston
# Processing Record 154| sumy
# Processing Record 155| port alfred
# Processing Record 156| gotsu
# Processing Record 157| cabedelo
# Processing Record 158| pimenta bueno
# Processing Record 159| stirion
# Processing Record 160| naron
# Processing Record 161| geraldton
# Processing Record 162| honiara
# Processing Record 163| troitsko-pechorsk
# Processing Record 164| thompson
# Processing Record 165| charters towers
# Processing Record 166| fairbanks
# Processing Record 167| elk city
# Processing Record 168| mouila
# Processing Record 169| aromashevo
# Processing Record 170| saint anthony
# Processing Record 171| olutanga
# Processing Record 172| binzhou
# Processing Record 173| zhigansk
# Processing Record 174| uyuni
# Processing Record 175| koslan
# Processing Record 176| namibe
# Processing Record 177| verkhnyaya toyma
# Processing Record 178| guerrero negro
# Processing Record 179| sobolevo
# Processing Record 180| akyab
# Processing Record 181| alikalia
# Processing Record 182| honningsvag
# Processing Record 183| victoria
# Processing Record 184| alofi
# Processing Record 185| bilibino
# karauzyak did not exist. Skipping...
# attawapiskat did not exist. Skipping...
# Processing Record 186| prado
# Processing Record 187| katobu
# Processing Record 188| hit
# Processing Record 189| elat
# Processing Record 190| klaksvik
# Processing Record 191| ilheus
# Processing Record 192| nikolskoye
# Processing Record 193| visnes
# Processing Record 194| ancud
# Processing Record 195| raga
# Processing Record 196| portland
# Processing Record 197| lubumbashi
# Processing Record 198| cidreira
# Processing Record 199| darhan
# karaul did not exist. Skipping...
# Processing Record 200| nagua
# Processing Record 201| azangaro
# Processing Record 202| kurumkan
# Processing Record 203| holzminden
# Processing Record 204| bengkulu
# Processing Record 205| moose factory
# Processing Record 206| san quintin
# Processing Record 207| nishihara
# vaitupu did not exist. Skipping...
# Processing Record 208| goderich
# ribeirao do pinhal did not exist. Skipping...
# Processing Record 209| seoul
# Processing Record 210| de aar
# Processing Record 211| sioux lookout
# Processing Record 212| aksu
# Processing Record 213| faanui
# Processing Record 214| narsaq
# Processing Record 215| bambous virieux
# santa cruz de rosales did not exist. Skipping...
# Processing Record 216| yulara
# Processing Record 217| pevek
# Processing Record 218| vostok
# Processing Record 219| ulladulla
# Processing Record 220| waipawa
# Processing Record 221| tapes
# Processing Record 222| kodiak
# Processing Record 223| olivenza
# Processing Record 224| ketchikan
# Processing Record 225| lebu
# Processing Record 226| maneadero
# Processing Record 227| batagay-alyta
# Processing Record 228| tasiilaq
# Processing Record 229| gebre guracha
# Processing Record 230| sinnai
# Processing Record 231| nome
# Processing Record 232| kiunga
# Processing Record 233| wanning
# Processing Record 234| qaqortoq
# Processing Record 235| yerofey pavlovich
# Processing Record 236| yeppoon
# Processing Record 237| sibiti
# Processing Record 238| staunton
# Processing Record 239| clevedon
# Processing Record 240| potlogi
# Processing Record 241| kochki
# Processing Record 242| mersing
# Processing Record 243| van
# grand river south east did not exist. Skipping...
# Processing Record 244| cherskiy
# Processing Record 245| bundaberg
# Processing Record 246| sovetskaya gavan
# Processing Record 247| kaitangata
# Processing Record 248| puerto suarez
# Processing Record 249| jaguaruna
# nizhneyansk did not exist. Skipping...
# Processing Record 250| svetlyy
# uroteppa did not exist. Skipping...
# Processing Record 251| port hardy
# Processing Record 252| baherden
# mergui did not exist. Skipping...
# Processing Record 253| dolores
# Processing Record 254| cockburn town
# Processing Record 255| pisco
# Processing Record 256| kruisfontein
# Processing Record 257| ambilobe
# Processing Record 258| uva
# Processing Record 259| vila do maio
# Processing Record 260| atar
# Processing Record 261| laguna
# Processing Record 262| floro
# Processing Record 263| nakuru
# Processing Record 264| wuxue
# Processing Record 265| lata
# Processing Record 266| tabou
# Processing Record 267| hovd
# Processing Record 268| vardo
# malwan did not exist. Skipping...
# mys shmidta did not exist. Skipping...
# Processing Record 269| northam
# cheuskiny did not exist. Skipping...
# labutta did not exist. Skipping...
# bolonchen did not exist. Skipping...
# Processing Record 270| kangaatsiaq
# Processing Record 271| olafsvik
# umzimvubu did not exist. Skipping...
# Processing Record 272| charlottesville
# Processing Record 273| airai
# Processing Record 274| melbu
# Processing Record 275| mount darwin
# Processing Record 276| vitry-le-francois
# Processing Record 277| burnie
# Processing Record 278| lavrentiya
# Processing Record 279| george town
# Processing Record 280| san fernando
# Processing Record 281| kupino
# Processing Record 282| panzhihua
# Processing Record 283| marsaxlokk
# linchuan did not exist. Skipping...
# Processing Record 284| canoinhas
# Processing Record 285| lom sak
# Processing Record 286| la paz
# Processing Record 287| santo tomas
# Processing Record 288| lagoa
# Processing Record 289| waverley
# Processing Record 290| makakilo city
# saleaula did not exist. Skipping...
# Processing Record 291| ilulissat
# Processing Record 292| yerbogachen
# Processing Record 293| sterling
# Processing Record 294| constitucion
# Processing Record 295| palu
# Processing Record 296| sao miguel do araguaia
# Processing Record 297| souillac
# Processing Record 298| dauphin
# samusu did not exist. Skipping...
# Processing Record 299| praia
# Processing Record 300| north bend
# Processing Record 301| bandarbeyla
# Processing Record 302| taltal
# Processing Record 303| cuajinicuilapa
# Processing Record 304| nouadhibou
# Processing Record 305| nantucket
# Processing Record 306| zyryanka
# Processing Record 307| calawag
# Processing Record 308| bethel
# Processing Record 309| tura
# Processing Record 310| vila velha
# Processing Record 311| otradnoye
# opobo did not exist. Skipping...
# Processing Record 312| narovchat
# Processing Record 313| soyo
# Processing Record 314| mount isa
# Processing Record 315| krosno
# Processing Record 316| yaan
# Processing Record 317| calama
# Processing Record 318| coos bay
# Processing Record 319| idlib
# Processing Record 320| chemal
# Processing Record 321| haines junction
# barentsburg did not exist. Skipping...
# Processing Record 322| peniche
# warqla did not exist. Skipping...
# Processing Record 323| gberia fotombu
# Processing Record 324| komsomolskiy
# Processing Record 325| manta
# Processing Record 326| saryg-sep
# Processing Record 327| tiksi
# Processing Record 328| chebsara
# Processing Record 329| howard springs
# Processing Record 330| miramar
# Processing Record 331| kjollefjord
# Processing Record 332| beisfjord
# Processing Record 333| kuah
# Processing Record 334| tateyama
# Processing Record 335| puri
# tepatitlan did not exist. Skipping...
# Processing Record 336| vestmannaeyjar
# Processing Record 337| eaton socon
# sataua did not exist. Skipping...
# Processing Record 338| kearney
# Processing Record 339| sechura
# Processing Record 340| masty
# Processing Record 341| ardmore
# Processing Record 342| ondjiva
# Processing Record 343| buraydah
# Processing Record 344| maceio
# Processing Record 345| tazovskiy
# Processing Record 346| deputatskiy
# Processing Record 347| aquiraz
# Processing Record 348| plettenberg bay
# Processing Record 349| haapiti
# abiy adi did not exist. Skipping...
# Processing Record 350| scottsbluff
# Processing Record 351| alice springs
# Processing Record 352| lebowakgomo
# Processing Record 353| bhaktapur
# Processing Record 354| poronaysk
# Processing Record 355| shetpe
# amderma did not exist. Skipping...
# Processing Record 356| hanstholm
# Processing Record 357| san esteban
# Processing Record 358| safaga
# Processing Record 359| neira
# Processing Record 360| chaman
# Processing Record 361| hasaki
# talawdi did not exist. Skipping...
# Processing Record 362| wasilla
# Processing Record 363| obidos
# Processing Record 364| meadow lake
# Processing Record 365| port lincoln
# Processing Record 366| mahebourg
# Processing Record 367| saurimo
# Processing Record 368| morgan city
# Processing Record 369| kungurtug
# yuzhno-yeniseyskiy did not exist. Skipping...
# Processing Record 370| isangel
# Processing Record 371| thinadhoo
# Processing Record 372| crestview
# Processing Record 373| mayor pablo lagerenza
# Processing Record 374| asau
# Processing Record 375| orange walk
# Processing Record 376| nioro
# Processing Record 377| guna
# Processing Record 378| ust-tarka
# Processing Record 379| matara
# Processing Record 380| margate
# Processing Record 381| uige
# Processing Record 382| santa cruz
# Processing Record 383| broome
# xiongshi did not exist. Skipping...
# Processing Record 384| saint george
# Processing Record 385| vila franca do campo
# angra did not exist. Skipping...
# Processing Record 386| toledo
# Processing Record 387| kavieng
# Processing Record 388| ardakan
# Processing Record 389| verkhoyansk
# Processing Record 390| mildura
# Processing Record 391| roald
# Processing Record 392| high rock
# meyungs did not exist. Skipping...
# Processing Record 393| ajdabiya
# Processing Record 394| takoradi
# Processing Record 395| lewiston
# Processing Record 396| pella
# Processing Record 397| zhangye
# Processing Record 398| luderitz
# Processing Record 399| opuwo
# Processing Record 400| raudeberg
# Processing Record 401| knyaze-volkonskoye
# Processing Record 402| meulaboh
# Processing Record 403| dunedin
# bansda did not exist. Skipping...
# Processing Record 404| katangli
# Processing Record 405| pitimbu
# cagayan de tawi-tawi did not exist. Skipping...
# Processing Record 406| sulangan
# Processing Record 407| naze
# Processing Record 408| gayny
# Processing Record 409| yuxia
# Processing Record 410| dongsheng
# Processing Record 411| amapa
# Processing Record 412| lasa
# Processing Record 413| khash
# Processing Record 414| komatipoort
# Processing Record 415| hobyo
# qafsah did not exist. Skipping...
# Processing Record 416| scarborough
# kazalinsk did not exist. Skipping...
# Processing Record 417| coruripe
# Processing Record 418| college
# Processing Record 419| emerald
# Processing Record 420| la ronge
# Processing Record 421| beringovskiy
# Processing Record 422| sabang
# Processing Record 423| puerto escondido
# halalo did not exist. Skipping...
# Processing Record 424| seydi
# Processing Record 425| riyadh
# Processing Record 426| kysyl-syr
# Processing Record 427| cordoba
# Processing Record 428| erenhot
# Processing Record 429| vredendal
# Processing Record 430| gambela
# Processing Record 431| ouegoa
# Processing Record 432| altay
# Processing Record 433| sapa
# Processing Record 434| puerto madero
# Processing Record 435| tuatapere
# Processing Record 436| san patricio
# Processing Record 437| teya
# Processing Record 438| acapulco
# Processing Record 439| santiago
# Processing Record 440| yichang
# Processing Record 441| chiusi
# Processing Record 442| angoche
# Processing Record 443| montalban
# Processing Record 444| lahij
# Processing Record 445| ciego de avila
# Processing Record 446| tiznit
# Processing Record 447| evensk
# kadykchan did not exist. Skipping...
# Processing Record 448| boyolangu
# Processing Record 449| kijang
# Processing Record 450| quesnel
# riaba did not exist. Skipping...
# Processing Record 451| tigzirt
# Processing Record 452| asyut
# Processing Record 453| calamba
# Processing Record 454| schruns
# Processing Record 455| mitsamiouli
# Processing Record 456| markova
# Processing Record 457| sao filipe
# Processing Record 458| balakhninskiy
# Processing Record 459| saint-francois
# Processing Record 460| beloha
# Processing Record 461| saint-jean-de-maurienne
# Processing Record 462| finschhafen
# Processing Record 463| cam ranh
# Processing Record 464| suntar
# Processing Record 465| shaoxing
# Processing Record 466| maine-soroa
# Processing Record 467| punta cardon
# Processing Record 468| half moon bay
# Processing Record 469| jawhar
# Processing Record 470| nadym
# Processing Record 471| lugovoy
# Processing Record 472| sydney
# Processing Record 473| bozhou
# anar darreh did not exist. Skipping...
# Processing Record 474| flinders
# Processing Record 475| santa fe
# Processing Record 476| conceicao do araguaia
# Processing Record 477| mobaye
# Processing Record 478| serrinha
# Processing Record 479| presidencia roque saenz pena
# Processing Record 480| sabha
# Processing Record 481| muros
# Processing Record 482| kharan
# Processing Record 483| peranamallur
# Processing Record 484| houma
# Processing Record 485| pangnirtung
# Processing Record 486| road town
# Processing Record 487| anicuns
# Processing Record 488| stornoway
# Processing Record 489| sahaspur
# Processing Record 490| hargeysa
# Processing Record 491| bayir
# Processing Record 492| tanout
# Processing Record 493| san ramon
# Processing Record 494| dingle
# Processing Record 495| carangola
# Processing Record 496| carauari
# Processing Record 497| uttaradit
# Processing Record 498| vao
# Processing Record 499| bela
# Processing Record 500| hamilton
# Processing Record 501| nhulunbuy
# tidore did not exist. Skipping...
# Processing Record 502| iskateley
# Processing Record 503| berlevag
# Processing Record 504| gaspe
# Processing Record 505| khandyga
# Processing Record 506| gupitan
# Processing Record 507| uruzgan
# Processing Record 508| stromness
# Processing Record 509| santa cruz cabralia
# Processing Record 510| camacha
# Processing Record 511| qasigiannguit
# Processing Record 512| ismailia
# Processing Record 513| south lake tahoe
# Processing Record 514| ixtapa
# Processing Record 515| el dorado
# Processing Record 516| masallatah
# Processing Record 517| grindavik
# Processing Record 518| beira
# Processing Record 519| opunake
# Processing Record 520| nizwa
# Processing Record 521| quatre cocos
# Processing Record 522| salsk
# Processing Record 523| westport
# Processing Record 524| bereda
# Processing Record 525| kanniyakumari
# Processing Record 526| clyde river
# Processing Record 527| barranca
# Processing Record 528| nyurba
# Processing Record 529| sal rei
# Processing Record 530| balkhash
# Processing Record 531| hofn
# balykshi did not exist. Skipping...
# Processing Record 532| mecca
# Processing Record 533| fort-shevchenko
# kawana waters did not exist. Skipping...
# Processing Record 534| broken hill
# Processing Record 535| xiazhen
# Processing Record 536| tigil
# Processing Record 537| tucurui
# Processing Record 538| stillwater
# Processing Record 539| lang suan
# Processing Record 540| san joaquin
# Processing Record 541| mount pleasant
# Processing Record 542| rzhanitsa
# Processing Record 543| yumen
# Processing Record 544| ciudad valles
# Processing Record 545| neuquen
# Processing Record 546| abu samrah
# Processing Record 547| swellendam
# Processing Record 548| iwaki
# Processing Record 549| genhe
# Processing Record 550| khani
# Processing Record 551| biak
# Processing Record 552| sorland
# Processing Record 553| ternate
# guata did not exist. Skipping...
# Processing Record 554| tomatlan
# Processing Record 555| lozuvatka
# zolotinka did not exist. Skipping...
# Processing Record 556| maymyo
# Processing Record 557| kargasok
# Processing Record 558| faya
# Processing Record 559| sawtell
# Processing Record 560| cabo san lucas
# Processing Record 561| balad
# Processing Record 562| pahrump
# ------------------------------
# End of Records

# %%
cities_data.dtypes
# Out:
# City          object
# Lat           object
# Lng           object
# Max Temp      object
# Humidity      object
# Cloudiness    object
# Wind Speed    object
# Country       object
# Date          object
# dtype: object

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_data["Country"].replace("",np.nan,inplace=True)
cities_data.dropna(subset=["Country"], inplace=True)
cities_data.reset_index(drop=True, inplace=True)
cities_data.to_csv(output_data_file)
cities_data.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
cities_data
# Out:
#                City    Lat     Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0        butaritari   3.07  172.79    80.28       85        100      10.45
# 1         saskylakh  71.92  114.08    49.53       58         37       4.79
# 2              hilo  19.73 -155.09     84.2       58          1       8.05
# 3         busselton -33.65  115.33    46.99       93         99       4.76
# 4        port blair  11.67   92.75     80.6       88         75       2.24
# ..              ...    ...     ...      ...      ...        ...        ...
# 558            faya  18.39   42.45     69.8       88         20       5.82
# 559         sawtell -30.38   153.1     57.2       76         12       8.05
# 560  cabo san lucas  22.89 -109.91     91.4       83         75      19.46
# 561           balad  34.02   44.15   100.11       11          0       8.19
# 562         pahrump  36.21 -115.98      104        9          0       1.01
#
#     Country        Date
# 0        KI  1595973771
# 1        RU  1595973961
# 2        US  1595973885
# 3        AU  1595973962
# 4        IN  1595973962
# ..      ...         ...
# 558      SA  1595974155
# 559      AU  1595974155
# 560      MX  1595974049
# 561      IQ  1595974156
# 562      US  1595974156
#
# [563 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#No cities with a humidity over 100%
cities_data.sort_values(by="Humidity",ascending=False)
# Out:
#               City    Lat     Lng Max Temp Humidity Cloudiness Wind Speed  \
# 503       berlevag  70.86   29.09       50      100         27       5.82
# 268          vardo  70.37   31.11     51.8      100         90      14.99
# 517      grindavik  63.84  -22.43       50      100         90       9.17
# 242        mersing   2.43  103.84     73.4      100        100        4.7
# 102  mount gambier -37.83  140.77     37.4      100         90       8.05
# ..             ...    ...     ...      ...      ...        ...        ...
# 286         la paz  -16.5  -68.15     60.8       10         20       5.82
# 188            hit  33.64   42.83   101.95        9          8       8.66
# 562        pahrump  36.21 -115.98      104        9          0       1.01
# 73        ngunguru -35.62   174.5       59        3        100      11.99
# 317         calama -22.47  -68.93     69.8        2          0      18.34
#
#     Country        Date
# 503      NO  1595974136
# 268      NO  1595974052
# 517      IS  1595974141
# 242      MY  1595974043
# 102      AU  1595973996
# ..      ...         ...
# 286      BO  1595973883
# 188      IQ  1595974025
# 562      US  1595974156
# 73       NZ  1595973986
# 317      CL  1595973929
#
# [563 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(cities_data["Lat"],cities_data["Max Temp"], edgecolors="black", zorder=3)
plt.title("City Latitude vs. Max Temperature (07/28/20)")
plt.xlabel("Latitude")
plt.ylabel("Temperature in Fahrenehit")
plt.xlim(-90,90)
plt.grid(linestyle="dashed", zorder=0)
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(cities_data["Lat"],cities_data["Humidity"], edgecolors="black", zorder=3)
plt.title("City Latitude vs. Humidity (07/28/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity Level")
plt.xlim(-90,90)
plt.grid(linestyle="dashed", zorder=0)
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_data["Lat"],cities_data["Cloudiness"], edgecolors="black", zorder=3)
plt.title("City Latitude vs. Cloudiness (07/28/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness Level")
plt.xlim(-90,90)
plt.grid(linestyle="dashed", zorder=0)
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_data["Lat"],cities_data["Wind Speed"], edgecolors="black", zorder=3)
plt.title("City Latitude vs. Wind Speed (07/28/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlim(-90,90)
plt.grid(linestyle="dashed", zorder=0)
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
#Northern
n_hem=cities_data.loc[cities_data["Lat"] > 0]
#Southern
s_hem=cities_data.loc[cities_data["Lat"] < 0]

# %%
n_hem.dtypes
# Out:
# City          object
# Lat           object
# Lng           object
# Max Temp      object
# Humidity      object
# Cloudiness    object
# Wind Speed    object
# Country       object
# Date          object
# dtype: object

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Linear regression
values=linregress(n_hem["Lat"],n_hem["Max Temp"])
values
# (slope,intercept,rvalue,pvalue,stderr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-184-c096be4af2f0> in <module>
#       1 #Linear regression
# ----> 2 values=linregress(n_hem["Lat"],n_hem["Max Temp"])
#       3 values
#       4 # (slope,intercept,rvalue,pvalue,stderr)
#
# ~\anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#     114
#     115     # average sum of squares:
# --> 116     ssxm, ssxym, ssyxm, ssym = np.cov(x, y, bias=1).flat
#     117     r_num = ssxym
#     118     r_den = np.sqrt(ssxm * ssym)
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2429             w *= aweights
#    2430
# -> 2431     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2432     w_sum = w_sum[0]
#    2433
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in average(a, axis, weights, returned)
#     426
#     427     if returned:
# --> 428         if scl.shape != avg.shape:
#     429             scl = np.broadcast_to(scl, avg.shape).copy()
#     430         return avg, scl
#
# AttributeError: 'float' object has no attribute 'shape'

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.39936284758885965

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10829462153873139

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.0008996079328825663

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.05768812657005063

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.0684912094859049

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.023371104533850804

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.03381889207758188
