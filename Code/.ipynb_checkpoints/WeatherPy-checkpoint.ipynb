# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint
from scipy.stats import linregress

# Import API key
from api_keys import owkey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Creating Dataframe
cities_data=pd.DataFrame(cities,columns=["City"])
labels=["Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Country","Date"]
for each_label in labels:
    cities_data[each_label]=""

# Fetching City Data
record=0
units="Imperial"
for index, row in cities_data.iterrows():
    city=row["City"]
    try:
        url_string=f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={owkey}&units={units}"
        response=requests.get(url_string)
        city_info=response.json()
        #feeding data into dataframe
        cities_data.loc[index,"Lat"]=city_info["coord"]["lat"]
        cities_data.loc[index,"Lng"]=city_info["coord"]["lon"]
        cities_data.loc[index,"Max Temp"]=city_info["main"]["temp_max"]
        cities_data.loc[index,"Humidity"]=city_info["main"]["humidity"]
        cities_data.loc[index,"Cloudiness"]=city_info["clouds"]["all"]
        cities_data.loc[index,"Wind Speed"]=city_info["wind"]["speed"]
        cities_data.loc[index,"Country"]=city_info["sys"]["country"]
        cities_data.loc[index,"Date"]=city_info["dt"]
        print(f"Processing Record {record}| {city}")
        record=record+1
    except KeyError:
        pass
        print(f"{city} did not exist. Skipping...")
print("-"*30)
print("End of Records")
# Out:
# Processing Record 0| talnakh
# Processing Record 1| bluff
# Processing Record 2| port alfred
# Processing Record 3| hobart
# Processing Record 4| qaanaaq
# Processing Record 5| lavrentiya
# Processing Record 6| khatanga
# Processing Record 7| kapaa
# Processing Record 8| palestine
# Processing Record 9| oksfjord
# Processing Record 10| kodiak
# Processing Record 11| nanortalik
# Processing Record 12| meleuz
# Processing Record 13| mataura
# Processing Record 14| ouro preto do oeste
# Processing Record 15| albany
# Processing Record 16| mehran
# Processing Record 17| rikitea
# Processing Record 18| taoudenni
# Processing Record 19| lompoc
# Processing Record 20| ushuaia
# Processing Record 21| codajas
# taolanaro did not exist. Skipping...
# Processing Record 22| saskylakh
# Processing Record 23| ancud
# Processing Record 24| vaini
# Processing Record 25| katsuura
# Processing Record 26| isangel
# Processing Record 27| cidreira
# Processing Record 28| atuona
# Processing Record 29| airai
# Processing Record 30| xai-xai
# Processing Record 31| mahebourg
# Processing Record 32| gambiran
# Processing Record 33| kahului
# Processing Record 34| alice springs
# Processing Record 35| maltahohe
# Processing Record 36| vila franca do campo
# amderma did not exist. Skipping...
# Processing Record 37| tateyama
# Processing Record 38| pustoshka
# Processing Record 39| cape town
# Processing Record 40| bolobo
# Processing Record 41| horadiz
# Processing Record 42| sioux lookout
# Processing Record 43| hithadhoo
# Processing Record 44| barguzin
# Processing Record 45| troitsko-pechorsk
# Processing Record 46| chuy
# Processing Record 47| esperance
# illoqqortoormiut did not exist. Skipping...
# Processing Record 48| thompson
# Processing Record 49| castro
# Processing Record 50| nome
# Processing Record 51| hilo
# Processing Record 52| waynesboro
# Processing Record 53| erenhot
# Processing Record 54| hermanus
# Processing Record 55| jamestown
# Processing Record 56| yellowknife
# Processing Record 57| saint-philippe
# Processing Record 58| bambous virieux
# Processing Record 59| ust-tsilma
# Processing Record 60| huarmey
# Processing Record 61| cacu
# Processing Record 62| ponta do sol
# Processing Record 63| matara
# Processing Record 64| burdur
# Processing Record 65| celestun
# Processing Record 66| tuktoyaktuk
# Processing Record 67| arequipa
# Processing Record 68| korla
# Processing Record 69| lebu
# Processing Record 70| mar del plata
# Processing Record 71| carnarvon
# Processing Record 72| valera
# Processing Record 73| guerrero negro
# Processing Record 74| sassandra
# Processing Record 75| hami
# Processing Record 76| avarua
# Processing Record 77| tiksi
# Processing Record 78| nikolskoye
# Processing Record 79| busselton
# Processing Record 80| tasiilaq
# Processing Record 81| mount abu
# Processing Record 82| faanui
# Processing Record 83| goderich
# Processing Record 84| bayan
# Processing Record 85| ajdabiya
# Processing Record 86| san carlos
# Processing Record 87| mpika
# Processing Record 88| yarmouth
# Processing Record 89| tottori
# Processing Record 90| bredasdorp
# Processing Record 91| dikson
# Processing Record 92| bethel
# Processing Record 93| kafanchan
# Processing Record 94| acapulco
# Processing Record 95| punta arenas
# Processing Record 96| liverpool
# Processing Record 97| arraial do cabo
# Processing Record 98| beringovskiy
# Processing Record 99| helong
# Processing Record 100| tangkak
# Processing Record 101| geraldton
# nguiu did not exist. Skipping...
# Processing Record 102| bardiyah
# Processing Record 103| port lincoln
# Processing Record 104| berdigestyakh
# Processing Record 105| saquarema
# Processing Record 106| iqaluit
# Processing Record 107| placido de castro
# Processing Record 108| nobres
# Processing Record 109| teguldet
# Processing Record 110| belaya gora
# Processing Record 111| souillac
# Processing Record 112| georgetown
# Processing Record 113| fortuna
# Processing Record 114| san pedro
# Processing Record 115| barrow
# Processing Record 116| hoquiam
# Processing Record 117| manggar
# sahrak did not exist. Skipping...
# Processing Record 118| katherine
# Processing Record 119| chifeng
# Processing Record 120| shenzhen
# Processing Record 121| srednekolymsk
# Processing Record 122| ust-nera
# Processing Record 123| lorengau
# karaul did not exist. Skipping...
# Processing Record 124| kumluca
# Processing Record 125| paamiut
# Processing Record 126| klaksvik
# Processing Record 127| mount pleasant
# Processing Record 128| kaitangata
# Processing Record 129| vardo
# Processing Record 130| gweta
# Processing Record 131| koplik
# Processing Record 132| boende
# Processing Record 133| tiznit
# Processing Record 134| pandan
# Processing Record 135| lebanon
# Processing Record 136| port-gentil
# Processing Record 137| luderitz
# Processing Record 138| itaituba
# Processing Record 139| sayanogorsk
# vaitupu did not exist. Skipping...
# Processing Record 140| butaritari
# Processing Record 141| port hardy
# Processing Record 142| wencheng
# Processing Record 143| haines junction
# Processing Record 144| swellendam
# Processing Record 145| synya
# Processing Record 146| bilibino
# Processing Record 147| elizabeth city
# Processing Record 148| saint-augustin
# Processing Record 149| tabou
# Processing Record 150| chokurdakh
# Processing Record 151| kroya
# Processing Record 152| khorixas
# saleaula did not exist. Skipping...
# Processing Record 153| torbay
# Processing Record 154| touros
# Processing Record 155| kaeo
# Processing Record 156| kloulklubed
# Processing Record 157| chimoio
# mys shmidta did not exist. Skipping...
# Processing Record 158| carlisle
# Processing Record 159| rawlins
# Processing Record 160| tuatapere
# Processing Record 161| xucheng
# Processing Record 162| pangnirtung
# Processing Record 163| quesnel
# Processing Record 164| umtata
# Processing Record 165| ostrovnoy
# Processing Record 166| djambala
# Processing Record 167| bud
# attawapiskat did not exist. Skipping...
# Processing Record 168| roma
# Processing Record 169| saint anthony
# Processing Record 170| yuxia
# Processing Record 171| roald
# Processing Record 172| jalu
# Processing Record 173| palmer
# Processing Record 174| richards bay
# Processing Record 175| alofi
# Processing Record 176| baoding
# Processing Record 177| ghanzi
# Processing Record 178| ketchikan
# Processing Record 179| joshimath
# Processing Record 180| samarai
# Processing Record 181| marienburg
# Processing Record 182| atasu
# Processing Record 183| upernavik
# Processing Record 184| murdochville
# Processing Record 185| porto novo
# Processing Record 186| inhambane
# Processing Record 187| sunrise manor
# Processing Record 188| umreth
# Processing Record 189| new norfolk
# Processing Record 190| dharapuram
# Processing Record 191| yaan
# Processing Record 192| turriff
# Processing Record 193| victoria
# Processing Record 194| half moon bay
# Processing Record 195| ushtobe
# Processing Record 196| mirador
# Processing Record 197| san patricio
# Processing Record 198| radcliff
# Processing Record 199| catuday
# Processing Record 200| bani
# Processing Record 201| port-cartier
# Processing Record 202| kizukuri
# Processing Record 203| najran
# Processing Record 204| leh
# Processing Record 205| olenino
# Processing Record 206| aviles
# Processing Record 207| berlevag
# Processing Record 208| qasigiannguit
# Processing Record 209| sucua
# Processing Record 210| craig
# Processing Record 211| bahia de caraquez
# Processing Record 212| puerto ayora
# Processing Record 213| umarkot
# Processing Record 214| nampa
# Processing Record 215| pokrovsk
# Processing Record 216| bandarbeyla
# Processing Record 217| port moresby
# Processing Record 218| mersing
# Processing Record 219| saldanha
# Processing Record 220| buraydah
# Processing Record 221| jinchang
# Processing Record 222| ville-marie
# Processing Record 223| salalah
# Processing Record 224| rincon
# Processing Record 225| sosnogorsk
# Processing Record 226| tonantins
# Processing Record 227| baykit
# Processing Record 228| tarakan
# Processing Record 229| trairi
# Processing Record 230| warmbad
# Processing Record 231| narsaq
# Processing Record 232| natchez
# Processing Record 233| buritis
# Processing Record 234| karambakkudi
# sentyabrskiy did not exist. Skipping...
# Processing Record 235| kattivakkam
# Processing Record 236| ust-maya
# kazalinsk did not exist. Skipping...
# Processing Record 237| labytnangi
# Processing Record 238| scarborough
# Processing Record 239| vanimo
# Processing Record 240| harper
# Processing Record 241| puerto gaitan
# Processing Record 242| longyearbyen
# tabiauea did not exist. Skipping...
# barentsburg did not exist. Skipping...
# Processing Record 243| siuna
# Processing Record 244| bredy
# Processing Record 245| provideniya
# Processing Record 246| saint-denis
# Processing Record 247| aranjuez
# Processing Record 248| ndele
# Processing Record 249| axim
# Processing Record 250| nueva gerona
# Processing Record 251| vila velha
# Processing Record 252| bilma
# wulanhaote did not exist. Skipping...
# Processing Record 253| plettenberg bay
# Processing Record 254| inuvik
# Processing Record 255| cabedelo
# Processing Record 256| laguna
# Processing Record 257| pemba
# Processing Record 258| mount isa
# Processing Record 259| soe
# Processing Record 260| dunedin
# grand centre did not exist. Skipping...
# Processing Record 261| novoshakhtinsk
# Processing Record 262| fiumicino
# Processing Record 263| akyab
# Processing Record 264| novikovo
# Processing Record 265| port hedland
# Processing Record 266| itarema
# Processing Record 267| norman wells
# Processing Record 268| eydhafushi
# Processing Record 269| sao joao da barra
# Processing Record 270| rapid valley
# Processing Record 271| henties bay
# Processing Record 272| pinawa
# Processing Record 273| agra
# Processing Record 274| vao
# belushya guba did not exist. Skipping...
# tabulbah did not exist. Skipping...
# Processing Record 275| naze
# Processing Record 276| krasnoselkup
# Processing Record 277| mandera
# Processing Record 278| deputatskiy
# Processing Record 279| shimoda
# Processing Record 280| zadonsk
# Processing Record 281| zhezkazgan
# Processing Record 282| gari
# Processing Record 283| chihuahua
# Processing Record 284| fairbanks
# Processing Record 285| latung
# Processing Record 286| egvekinot
# Processing Record 287| kununurra
# Processing Record 288| saint george
# Processing Record 289| sechura
# Processing Record 290| malanje
# Processing Record 291| tilichiki
# Processing Record 292| nabire
# Processing Record 293| codrington
# Processing Record 294| makakilo city
# Processing Record 295| wattegama
# Processing Record 296| kruisfontein
# Processing Record 297| matamoros
# Processing Record 298| maceio
# barawe did not exist. Skipping...
# Processing Record 299| uyutne
# Processing Record 300| vestmannaeyjar
# nizhneyansk did not exist. Skipping...
# Processing Record 301| humaita
# Processing Record 302| aktau
# Processing Record 303| njeru
# Processing Record 304| muros
# Processing Record 305| jishou
# Processing Record 306| bajil
# Processing Record 307| pisco
# Processing Record 308| bengkulu
# Processing Record 309| quatre cocos
# Processing Record 310| kirakira
# Processing Record 311| neka
# Processing Record 312| te anau
# Processing Record 313| izvestkovyy
# Processing Record 314| mandalgovi
# Processing Record 315| abha
# Processing Record 316| hasaki
# Processing Record 317| iracoubo
# Processing Record 318| tirumullaivasal
# Processing Record 319| sokoto
# Processing Record 320| cabo san lucas
# Processing Record 321| avera
# Processing Record 322| champerico
# Processing Record 323| lata
# Processing Record 324| gashua
# Processing Record 325| aklavik
# Processing Record 326| nerchinskiy zavod
# Processing Record 327| kilindoni
# Processing Record 328| college
# Processing Record 329| waipawa
# Processing Record 330| novopavlovka
# Processing Record 331| wawa
# Processing Record 332| alagoinha
# Processing Record 333| kalengwa
# Processing Record 334| acarau
# Processing Record 335| nyuksenitsa
# Processing Record 336| salym
# Processing Record 337| havre-saint-pierre
# Processing Record 338| aleksandrov gay
# Processing Record 339| clarence town
# Processing Record 340| nemuro
# Processing Record 341| ewa beach
# Processing Record 342| broken hill
# Processing Record 343| xuddur
# Processing Record 344| dulce nombre de culmi
# Processing Record 345| luanda
# Processing Record 346| taitung
# Processing Record 347| irbil
# Processing Record 348| khudumelapye
# Processing Record 349| kristinehamn
# Processing Record 350| east london
# Processing Record 351| maningrida
# Processing Record 352| coquimbo
# Processing Record 353| sakakah
# galiwinku did not exist. Skipping...
# Processing Record 354| ruteng
# Processing Record 355| longkou
# Processing Record 356| dingle
# Processing Record 357| kribi
# Processing Record 358| the valley
# Processing Record 359| piripiri
# Processing Record 360| arshan
# Processing Record 361| brae
# grand river south east did not exist. Skipping...
# tumannyy did not exist. Skipping...
# Processing Record 362| rabo de peixe
# Processing Record 363| forestville
# Processing Record 364| jumla
# Processing Record 365| necochea
# Processing Record 366| ribeira grande
# eskasem did not exist. Skipping...
# Processing Record 367| vrangel
# Processing Record 368| tromso
# Processing Record 369| saint pete beach
# Processing Record 370| lasa
# Processing Record 371| sinjai
# Processing Record 372| kyra
# Processing Record 373| silver city
# Processing Record 374| shumskiy
# Processing Record 375| sorland
# Processing Record 376| sitka
# Processing Record 377| general roca
# Processing Record 378| gannan
# Processing Record 379| puerto escondido
# Processing Record 380| oranjemund
# Processing Record 381| beloha
# Processing Record 382| owando
# louisbourg did not exist. Skipping...
# Processing Record 383| kaduqli
# Processing Record 384| atikokan
# Processing Record 385| rafiganj
# Processing Record 386| kavaratti
# Processing Record 387| lyantonde
# Processing Record 388| sunyani
# Processing Record 389| yerbogachen
# Processing Record 390| puro
# Processing Record 391| anda
# Processing Record 392| birin
# Processing Record 393| lacombe
# Processing Record 394| broome
# Processing Record 395| portland
# Processing Record 396| biltine
# Processing Record 397| canatlan
# Processing Record 398| sao filipe
# Processing Record 399| hamilton
# Processing Record 400| shingu
# Processing Record 401| port augusta
# Processing Record 402| san quintin
# Processing Record 403| moreira sales
# Processing Record 404| manta
# gangotri did not exist. Skipping...
# Processing Record 405| lagoa
# Processing Record 406| christchurch
# Processing Record 407| noyabrsk
# Processing Record 408| camacha
# Processing Record 409| flinders
# Processing Record 410| praia
# Processing Record 411| zyryanka
# Processing Record 412| skibbereen
# Processing Record 413| diffa
# Processing Record 414| tessalit
# Processing Record 415| baruun-urt
# Processing Record 416| port elizabeth
# Processing Record 417| susanville
# Processing Record 418| juegang
# Processing Record 419| lapeer
# Processing Record 420| bambanglipuro
# Processing Record 421| leningradskiy
# lolua did not exist. Skipping...
# Processing Record 422| erzin
# Processing Record 423| ilulissat
# Processing Record 424| charters towers
# Processing Record 425| krapivinskiy
# Processing Record 426| kimbe
# tanshui did not exist. Skipping...
# Processing Record 427| port macquarie
# Processing Record 428| yinchuan
# Processing Record 429| severo-kurilsk
# Processing Record 430| maholi
# Processing Record 431| itoman
# Processing Record 432| san isidro
# Processing Record 433| nuuk
# Processing Record 434| tarazona
# Processing Record 435| cam ranh
# Processing Record 436| tura
# Processing Record 437| saharanpur
# Processing Record 438| preobrazheniye
# Processing Record 439| xining
# Processing Record 440| fort frances
# Processing Record 441| yanam
# Processing Record 442| quixeramobim
# Processing Record 443| kindu
# Processing Record 444| bintulu
# Processing Record 445| nisia floresta
# Processing Record 446| east foothills
# Processing Record 447| saint john
# Processing Record 448| nogales
# Processing Record 449| coihaique
# Processing Record 450| finschhafen
# Processing Record 451| sergeyevka
# Processing Record 452| kenai
# Processing Record 453| kautokeino
# rungata did not exist. Skipping...
# Processing Record 454| aljezur
# Processing Record 455| saint-pierre
# Processing Record 456| kostomuksha
# Processing Record 457| svetlogorsk
# Processing Record 458| road town
# Processing Record 459| flin flon
# Processing Record 460| severnyy
# Processing Record 461| tal
# Processing Record 462| kysyl-syr
# Processing Record 463| awjilah
# Processing Record 464| vestmanna
# Processing Record 465| tazovskiy
# Processing Record 466| launceston
# Processing Record 467| moron
# rolim de moura did not exist. Skipping...
# Processing Record 468| mehamn
# Processing Record 469| iranduba
# Processing Record 470| baduria
# Processing Record 471| aswan
# Processing Record 472| rubbestadneset
# Processing Record 473| gazli
# Processing Record 474| powell river
# Processing Record 475| liwale
# Processing Record 476| husavik
# Processing Record 477| koslan
# Processing Record 478| yeniseysk
# Processing Record 479| marawi
# Processing Record 480| karratha
# Processing Record 481| mahendragarh
# Processing Record 482| coahuayana
# yomitan did not exist. Skipping...
# Processing Record 483| senador jose porfirio
# Processing Record 484| dubbo
# Processing Record 485| kudahuvadhoo
# Processing Record 486| juneau
# Processing Record 487| shubarshi
# Processing Record 488| chyhyryn
# Processing Record 489| meulaboh
# Processing Record 490| yumen
# Processing Record 491| inverell
# Processing Record 492| anadyr
# tsihombe did not exist. Skipping...
# blonduos did not exist. Skipping...
# kuche did not exist. Skipping...
# Processing Record 493| islahiye
# Processing Record 494| wabana
# Processing Record 495| puerto quijarro
# Processing Record 496| konstantinovka
# Processing Record 497| meadow lake
# Processing Record 498| nouadhibou
# Processing Record 499| svetlyy
# Processing Record 500| caibarien
# babanusah did not exist. Skipping...
# Processing Record 501| bulgan
# Processing Record 502| carahue
# Processing Record 503| kalmunai
# Processing Record 504| sokolow podlaski
# Processing Record 505| andenes
# Processing Record 506| grindavik
# Processing Record 507| kalmar
# Processing Record 508| bonfim
# Processing Record 509| namibe
# Processing Record 510| constitucion
# Processing Record 511| forio
# Processing Record 512| enid
# Processing Record 513| amahai
# zarakes did not exist. Skipping...
# Processing Record 514| mbandaka
# Processing Record 515| sinnamary
# Processing Record 516| kawalu
# Processing Record 517| sirawai
# Processing Record 518| skjervoy
# Processing Record 519| pevek
# Processing Record 520| fort-shevchenko
# Processing Record 521| kostino
# Processing Record 522| namatanai
# miranorte did not exist. Skipping...
# Processing Record 523| kangaatsiaq
# taburi did not exist. Skipping...
# ji-parana did not exist. Skipping...
# Processing Record 524| iralaya
# Processing Record 525| padang
# Processing Record 526| bueno brandao
# Processing Record 527| longavi
# Processing Record 528| killybegs
# Processing Record 529| dongsheng
# Processing Record 530| goroka
# Processing Record 531| rognan
# Processing Record 532| aonla
# Processing Record 533| jiaojiang
# Processing Record 534| canoa
# Processing Record 535| ravar
# Processing Record 536| okhotsk
# Processing Record 537| srandakan
# Processing Record 538| cayenne
# Processing Record 539| keetmanshoop
# Processing Record 540| srikakulam
# Processing Record 541| batagay-alyta
# malwan did not exist. Skipping...
# Processing Record 542| zhuhai
# Processing Record 543| aykhal
# Processing Record 544| kavieng
# Processing Record 545| omboue
# Processing Record 546| kontagora
# Processing Record 547| sainte-marie
# Processing Record 548| bondowoso
# Processing Record 549| karpogory
# Processing Record 550| pangody
# Processing Record 551| ereymentau
# maloshuyka did not exist. Skipping...
# Processing Record 552| chulym
# Processing Record 553| nizhniy odes
# Processing Record 554| mbini
# Processing Record 555| plouzane
# Processing Record 556| mosquera
# Processing Record 557| lakes entrance
# Processing Record 558| caravelas
# Processing Record 559| los andes
# Processing Record 560| hofn
# Processing Record 561| matagami
# Processing Record 562| pafos
# Processing Record 563| tame
# Processing Record 564| bathsheba
# ------------------------------
# End of Records

# %%
#Convert columns to floats
cities_data[["Lat","Lng","Humidity","Cloudiness","Wind Speed",
             "Max Temp"]]=cities_data[["Lat","Lng","Humidity","Cloudiness","Wind Speed","Max Temp"]].apply(pd.to_numeric,axis=1)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_data["Country"].replace("",np.nan,inplace=True)
cities_data.dropna(subset=["Country"], inplace=True)
cities_data.reset_index(drop=True, inplace=True)
cities_data.to_csv(output_data_file)
cities_data.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %%
cities_data
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        talnakh  69.49   88.40     60.80      67.0        34.0        8.95
# 1          bluff -46.60  168.33     50.32      91.0       100.0       13.80
# 2    port alfred -33.59   26.89     60.57      70.0         0.0       14.52
# 3         hobart -42.88  147.33     48.20      61.0        13.0       12.75
# 4        qaanaaq  77.48  -69.36     42.49      73.0        70.0        2.13
# ..           ...    ...     ...       ...       ...         ...         ...
# 560         hofn  64.25  -15.21     53.60      76.0        20.0       12.75
# 561     matagami  49.75  -77.63     62.60      93.0        75.0        4.41
# 562        pafos  34.77   32.42     87.80      62.0         0.0       12.75
# 563         tame   6.46  -71.73     84.72      65.0        25.0        5.55
# 564    bathsheba  13.22  -59.52     87.80      74.0        40.0       24.16
#
#     Country        Date
# 0        RU  1596036971
# 1        NZ  1596036919
# 2        ZA  1596036937
# 3        AU  1596036878
# 4        GL  1596036972
# ..      ...         ...
# 560      IS  1596037161
# 561      CA  1596037161
# 562      CY  1596037162
# 563      CO  1596037162
# 564      BB  1596037162
#
# [565 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#No cities with a humidity over 100%
cities_data.sort_values(by="Humidity",ascending=False)
# Out:
#                  City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 401      port augusta -32.50  137.77     46.40     100.0         0.0
# 425      krapivinskiy  55.00   86.81     62.60     100.0        40.0
# 116           hoquiam  46.98 -123.89     57.99     100.0        90.0
# 114         san pedro  14.35  121.02     77.00     100.0       100.0
# 113           fortuna  40.60 -124.16     54.00     100.0        90.0
# ..                ...    ...     ...       ...       ...         ...
# 414          tessalit  20.20    1.01    105.39      11.0         0.0
# 353           sakakah  29.97   40.21    116.60       8.0        40.0
# 67           arequipa -16.40  -71.53     64.40       7.0         0.0
# 155              kaeo -35.10  173.78     55.00       3.0       100.0
# 369  saint pete beach  27.73  -82.74     89.01       1.0       100.0
#
#      Wind Speed Country        Date
# 401        4.70      AU  1596037106
# 425        4.47      RU  1596037114
# 116        1.52      US  1596036946
# 114        4.70      PH  1596037008
# 113        2.48      US  1596037008
# ..          ...     ...         ...
# 414        8.08      ML  1596037110
# 353        4.70      SA  1596037090
# 67         5.82      PE  1596036811
# 155        5.99      NZ  1596037023
# 369        1.01      US  1596037096
#
# [565 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(cities_data["Lat"],cities_data["Max Temp"], edgecolors="black", zorder=3)
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature in Fahrenehit")
plt.xlim(-90,90)
plt.grid(linestyle="dashed", zorder=0)
plt.savefig("../output_data/plot_1.png")
plt.show()

# %% [markdown]
# This scatter plot shows that the further you get away from the equater the colder it tends to gets. There does appear to be a good correlation between latitude and temperature.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(cities_data["Lat"],cities_data["Humidity"], edgecolors="black", zorder=3)
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity Level")
plt.xlim(-90,90)
plt.grid(linestyle="dashed", zorder=0)
plt.savefig("../output_data/plot_2.png")
plt.show()

# %% [markdown]
# This scatter plot shows humidity levels compared to the latitude. There does not appear to be any coorelation between latitude and humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_data["Lat"],cities_data["Cloudiness"], edgecolors="black", zorder=3)
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness Level")
plt.xlim(-90,90)
plt.grid(linestyle="dashed", zorder=0)
plt.savefig("../output_data/plot_3.png")
plt.show()

# %% [markdown]
# This scatter plot shows latitude vs cloudiness. Again, there is no visible coorelation between the two.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_data["Lat"],cities_data["Wind Speed"], edgecolors="black", zorder=3)
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlim(-90,90)
plt.grid(linestyle="dashed", zorder=0)
plt.savefig("../output_data/plot_4.png")
plt.show()

# %% [markdown]
# This scatter plot shows Latitude vs Wind Speed. There is no visible coorelation between the two.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def plot_tool(x_value,y_value,x_label,y_label,title,x_min,x_max):    
    slope,intercept,rvalue,pvalue,stderr=linregress(x_value,y_value)
    yline=slope*x_value+intercept
    plt.scatter(x_value,y_value,edgecolors="black", zorder=3)
    plt.plot(x_value,yline, color="salmon")
    plt.annotate(f"y={round(slope,2)}x+{round(intercept,2)}",(x_min+5,min(y_value)), color="salmon")
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.xlim(x_min,x_max)
    plt.grid(linestyle="dashed", zorder=0)
    print(f"The R Sqaured value is = {rvalue**2}")
    plt.savefig(f"../output_data/{title}.png")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
#Northern
n_hem=cities_data.loc[cities_data["Lat"] > 0]
#Southern
s_hem=cities_data.loc[cities_data["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Linear regression
plot_tool(x_value=n_hem["Lat"],y_value=n_hem["Max Temp"],x_label="Latitude",x_min=-10,x_max=90,
          y_label="Temperature in Fahrenehit",title="Latitude vs. Max Temp (Northern Hemisphere)")
# Out:
# The R Sqaured value is = 0.4877221040571791

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plot_tool(x_value=s_hem["Lat"],y_value=s_hem["Max Temp"],x_label="Latitude",x_min=-70,x_max=10,
          y_label="Temperature in Fahrenehit",title="Latitude vs. Max Temp (Southern Hemisphere)")
# Out:
# The R Sqaured value is = 0.6358605499090668

# %% [markdown]
# These plots show the correlation between latitude and max temperature. The R squared value is fairly close to 1, meaning this line is a fairly good prediction.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plot_tool(x_value=n_hem["Lat"],y_value=n_hem["Humidity"],x_label="Latitude",x_min=-10,x_max=90,
          y_label="Humidity (%)",title="Latitude vs. Humidity Level (Northern Hemisphere)")
# Out:
# The R Sqaured value is = 0.005461835856308714

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plot_tool(x_value=s_hem["Lat"],y_value=s_hem["Humidity"],x_label="Latitude",x_min=-60,x_max=10,
          y_label="Humidity (%)",title="Latitude vs. Humidity Level (Southern Hemisphere)")
# Out:
# The R Sqaured value is = 0.024880898304514603

# %% [markdown]
# The two plots above show the humidty level compared to the latitude for each hemisphere. The R sqaured values are very low, indicatign the line is a poor predictor.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plot_tool(x_value=n_hem["Lat"],y_value=n_hem["Cloudiness"],x_label="Latitude",x_min=-10,x_max=100,
          y_label="Cloudiness (%)",title="Latitude vs. Cloudiness Level (Northern Hemisphere)")
# Out:
# The R Sqaured value is = 0.005310116596658759

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plot_tool(x_value=s_hem["Lat"],y_value=s_hem["Cloudiness"],x_label="Latitude",x_min=-60,x_max=10,
          y_label="Cloudiness (%)",title="Latitude vs. Cloudiness Level (Southern Hemisphere)")
# Out:
# The R Sqaured value is = 0.012757226556355422

# %% [markdown]
# The two plots above show the cloudiness level compared to the latitude for each hemisphere. The R sqaured values are very low, indicatign the line is a poor predictor.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plot_tool(x_value=n_hem["Lat"],y_value=n_hem["Wind Speed"],x_label="Latitude",x_min=-10,x_max=100,
          y_label="Wind Speed (mph)",title="Latitude vs. Wind Speed (Northern Hemisphere)")
# Out:
# The R Sqaured value is = 0.007247290206780487

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plot_tool(x_value=s_hem["Lat"],y_value=s_hem["Wind Speed"],x_label="Latitude",x_min=-60,x_max=10,
          y_label="Wind Speed (mph)",title="Latitude vs. Wind Speed(Southern Hemisphere)")
# Out:
# The R Sqaured value is = 0.003435950880870828

# %% [markdown]
# The two plots above show the wind speed compared to the latitude for each hemisphere. The R sqaured values are very low, indicatign the line is a poor predictor.
